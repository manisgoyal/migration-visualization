# %%
pip install pycountry

# %%
import pandas as pd
import pycountry

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('updated_file.csv', keep_default_na=False)

# Add a new column to the DataFrame with the country code
def get_country_code(country_name):
    try:
        return pycountry.countries.lookup(country_name).alpha_2
    except LookupError:
        # If the country name is not recognized by pycountry, return None
        return None

# %%
df[df['Source_country_code'].isna()]
# Out:
# Empty DataFrame
# Columns: [Year, Source, Value, Target, lat_dest, lon_dest, lat_org, lon_org, weight, Source_country_code]
# Index: []

# %%
df['Target_country_code'] = df['Target'].apply(get_country_code)

df
# Out:
#       Year                                 Source  Value  \
# 0     1980  Congo, the Democratic Republic of the  20000
# 1     1980                                Namibia  50000
# 2     1980                           South Africa   5000
# 3     1980                            Afghanistan   1500
# 4     1980  Congo, the Democratic Republic of the  50750
# ...    ...                                    ...    ...
# 9234  2014                                Burundi   2501
# 9235  2014  Congo, the Democratic Republic of the  18598
# 9236  2014                                 Rwanda   1904
# 9237  2014                                Somalia   2314
# 9238  2014  Congo, the Democratic Republic of the   4866
#
#                     Target  lat_dest  lon_dest  lat_org  lon_org    weight  \
# 0                   Angola     -12.5      18.5      0.0     25.0  0.616031
# 1                   Angola     -12.5      18.5    -22.0     17.0  0.704519
# ...

# %%
# Write the updated DataFrame back to a new CSV file
df.to_csv('updated_file1.csv', index=False)
